# %%
import time
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
import pandas as pd
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# #### Q1: Write a python program to scrape data for “Data Analyst” Job position in “Bangalore” location. You have to scrape the job-title, job-location, company_name, experience_required. You have to scrape first 10 jobs data.
# ##### This task will be done in following steps:
#     1. First get the webpage https://www.naukri.com/
#     2. Enter “Data Analyst” in “Skill, Designations, Companies” field and enter “Bangalore” in “enter the location” field.
#     3. Then click the search button.
#     4. Then scrape the data for the first 10 jobs results you get.
#     5. Finally create a dataframe of the scraped data.
# ###### Note: All of the above steps have to be done in code. No step is to be done manually.

# %%
PATH = 'C:\Program Files (x86)\chromedriver.exe'
driver = webdriver.Chrome(PATH)

# %%
driver.get('https://www.naukri.com/')

# %%
driver.find_element_by_xpath('//*[@id="root"]/div[2]/div[3]/div/div/div[1]/div/div/div/input').send_keys('Data Analyst')

# %%
driver.find_element_by_xpath('//*[@id="root"]/div[2]/div[3]/div/div/div[3]/div/div/div/input').send_keys('Bangalore')

# %%
driver.find_element_by_xpath('//*[@id="root"]/div[2]/div[3]/div/div/div[6]').click()

# %%
title = driver.find_elements_by_xpath('//a[@class="title fw500 ellipsis"]')
title[0:10]
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="03be3481dc395fa1f44494383a7ebc53", element="195d410c-d853-4e84-a644-266a4cfb6252")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="03be3481dc395fa1f44494383a7ebc53", element="39e1b8ab-ca6d-421e-9d92-b20be685f5b0")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="03be3481dc395fa1f44494383a7ebc53", element="25877d1d-ed82-4ad8-bc4a-fd35e7919bba")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="03be3481dc395fa1f44494383a7ebc53", element="ea99c6c3-e768-4d38-8dfa-48356e78930d")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="03be3481dc395fa1f44494383a7ebc53", element="8b7d987a-cb2e-40e7-97e8-62a2e88b1dc3")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="03be3481dc395fa1f44494383a7ebc53", element="f6ec3cc7-5c06-4db5-bfe2-fc572cf2754f")>,
# ...

# %%
Job_Titles = []
for i in title:
    Job_Titles.append(i.text)
Job_Titles[:10]
# Out:
# ['Sr Domain Expert -Data Analysts',
#  'Senior Data Analyst (Digital Services Analytics)',
#  'Senior Data Analyst',
#  'Senior Data Analyst - Collibra',
#  'Data Analyst - IIM/ISB/MDI/FMS/SP Jain',
#  'Staff Business Data Analyst - FDP',
#  'Data Analyst',
#  'Data Analyst 2',
#  'Senior Professional Data Analyst',
#  'Data Analyst - Python/Artificial Intelligence']

# %%
company = driver.find_elements_by_xpath('//a[@class="subTitle ellipsis fleft"]')
company[0:10]
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="03be3481dc395fa1f44494383a7ebc53", element="8b482af8-df4f-4bbc-847b-02d12838a312")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="03be3481dc395fa1f44494383a7ebc53", element="4b3a4420-57a9-4242-b1a5-8e4a7586a26b")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="03be3481dc395fa1f44494383a7ebc53", element="baf756f9-ea21-490e-bd5d-32e3733014dc")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="03be3481dc395fa1f44494383a7ebc53", element="f71cac14-ea28-4fde-bc21-083d06066a12")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="03be3481dc395fa1f44494383a7ebc53", element="c27dc929-09d1-4369-8e9a-3344e934286e")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="03be3481dc395fa1f44494383a7ebc53", element="518df88d-6f14-417f-924b-59c8e3d6f48a")>,
# ...

# %%
Organization = []
for i in company:
    Organization.append(i.text)
Organization[:10]
# Out:
# ['Siemens',
#  'Dell Technologies',
#  'Intel',
#  'Shell',
#  'K12 Techno Services Pvt Ltd',
#  'Intuit Inc.',
#  'Vedantu Innovations',
#  'PayPal',
#  'DXC Technology',
#  'iMindYourBusiness']

# %%
Exp = driver.find_elements_by_xpath('//li[@class="fleft grey-text br2 placeHolderLi experience"]/span[1]')
Exp[0:10]
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="03be3481dc395fa1f44494383a7ebc53", element="9b51d8c3-44eb-44cb-a832-ba1c88d7d8c7")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="03be3481dc395fa1f44494383a7ebc53", element="8384ab38-604b-4fde-bf04-dddba07f5773")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="03be3481dc395fa1f44494383a7ebc53", element="5eb6d255-062a-48cf-8bee-34a45d6936fc")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="03be3481dc395fa1f44494383a7ebc53", element="22dbb1f5-5f13-413a-af70-92fabb006003")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="03be3481dc395fa1f44494383a7ebc53", element="da7a5c05-3374-4cb4-956f-7c83bf1fd8cd")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="03be3481dc395fa1f44494383a7ebc53", element="44b69589-ce88-46c5-a778-d788e51e2a25")>,
# ...

# %%
Experience = []
for i in Exp:
    Experience.append(i.text)
Experience[:10]
# Out:
# ['0-10 Yrs',
#  '1-6 Yrs',
#  '3-8 Yrs',
#  '8-12 Yrs',
#  '4-9 Yrs',
#  '5-7 Yrs',
#  '0-3 Yrs',
#  '5-8 Yrs',
#  '3-7 Yrs',
#  '0-2 Yrs']

# %%
loc = driver.find_elements_by_xpath('//li[@class="fleft grey-text br2 placeHolderLi location"]/span[1]')
loc[0:10]
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="03be3481dc395fa1f44494383a7ebc53", element="a417a9ad-d7f0-44bb-8e1b-d4865b5d7c7b")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="03be3481dc395fa1f44494383a7ebc53", element="9f874837-0d8a-406f-abc0-6d44bceca7f4")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="03be3481dc395fa1f44494383a7ebc53", element="bd0407c5-64a2-4b9e-a1ba-3df841bd71f5")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="03be3481dc395fa1f44494383a7ebc53", element="7e362259-44e0-4775-b144-23125b3889de")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="03be3481dc395fa1f44494383a7ebc53", element="2e458322-7747-45e0-b214-8fab793fec51")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="03be3481dc395fa1f44494383a7ebc53", element="17b83e97-da7d-4a4f-9c2d-384e5b8dedf7")>,
# ...

# %%
Location = []
for i  in loc:
    Location.append(i.text)
Location[:10]
# Out:
# ['Bangalore/Bengaluru',
#  'Bangalore/Bengaluru',
#  'Bangalore/Bengaluru',
#  'Bangalore/Bengaluru',
#  'Bangalore/Bengaluru',
#  'Bangalore/Bengaluru',
#  'Bangalore/Bengaluru',
#  'Bangalore/Bengaluru',
#  'Bangalore/Bengaluru',
#  'Kolkata, Mumbai, Visakhapatnam, Hyderabad/Secunderabad, Pune, Chennai, Ahmedabad, Delhi / NCR, Bangalore/Bengaluru']

# %%
Job_Search = pd.DataFrame({})
Job_Search['Job Title'] = Job_Titles
Job_Search['Organization'] = Organization
Job_Search['Experience']=Experience
Job_Search['Location']=Location
Job_Search=Job_Search[:10]
Job_Search
# Out:
#                                           Job Title  \
# 0                   Sr Domain Expert -Data Analysts
# 1  Senior Data Analyst (Digital Services Analytics)
# 2                               Senior Data Analyst
# 3                    Senior Data Analyst - Collibra
# 4            Data Analyst - IIM/ISB/MDI/FMS/SP Jain
# 5                 Staff Business Data Analyst - FDP
# 6                                      Data Analyst
# 7                                    Data Analyst 2
# 8                  Senior Professional Data Analyst
# 9     Data Analyst - Python/Artificial Intelligence
#
#                   Organization Experience  \
# 0                      Siemens   0-10 Yrs
# 1            Dell Technologies    1-6 Yrs
# 2                        Intel    3-8 Yrs
# 3                        Shell   8-12 Yrs
# 4  K12 Techno Services Pvt Ltd    4-9 Yrs
# 5                  Intuit Inc.    5-7 Yrs
# 6          Vedantu Innovations    0-3 Yrs
# 7                       PayPal    5-8 Yrs
# ...

# %%
driver.close()

# %% [markdown]
# #### Q2: Write a python program to scrape data for “Data Scientist” Job position in “Bangalore” location. You have to scrape the job-title, job-location, company_name. You have to scrape first 10 jobs data.
#
# ##### This task will be done in following steps:
#     1. First get the webpage https://www.naukri.com/
#     2. Enter “Data Scientist” in “Skill, Designations, Companies” field and enter “Bangalore” in “enter the location” field.
#     3. Then click the search button.
#     4. Then scrape the data for the first 10 jobs results you get.
#     5. Finally create a dataframe of the scraped data.
# ##### Note: All of the above steps have to be done in code. No step is to be done manually.

# %%
PATH = 'C:\Program Files (x86)\chromedriver.exe'
driver = webdriver.Chrome(PATH)
driver.get('https://www.naukri.com/')

# %%
driver.find_element_by_xpath('//*[@id="root"]/div[2]/div[3]/div/div/div[1]/div/div/div/input').send_keys('Data Scientist')

# %%
driver.find_element_by_xpath('//*[@id="root"]/div[2]/div[3]/div/div/div[3]/div/div/div/input').send_keys('Bangalore')

# %%
driver.find_element_by_xpath('/html/body/div/div[2]/div[3]/div/div/div[6]').click()

# %%
title = driver.find_elements_by_xpath('//a[@class="title fw500 ellipsis"]')
title[0:10]
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="aa473fde1dfc2e6b929b04777de67dc4", element="4ee6d393-7238-4bbc-9d7f-42d9c6c32845")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="aa473fde1dfc2e6b929b04777de67dc4", element="f6196ac7-8990-4193-8733-bbb3db692a0b")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="aa473fde1dfc2e6b929b04777de67dc4", element="fe56c32e-526c-4048-a3d1-d0ce315c0749")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="aa473fde1dfc2e6b929b04777de67dc4", element="6514642e-5db1-4c3e-9072-a67b1487ae7e")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="aa473fde1dfc2e6b929b04777de67dc4", element="d0b42b9f-ca4d-4e14-96c6-4e5bdfa9ee3d")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="aa473fde1dfc2e6b929b04777de67dc4", element="88f59a77-10ac-4b4c-92ca-225f39a010c1")>,
# ...

# %%
Job_Title = []
for i in title:
    Job_Title.append(i.text)
Job_Title[:10]
# Out:
# ['Senior Data Scientist',
#  'Data Scientist',
#  'Analyst - Data Scientist',
#  'Senior Data Scientist',
#  'Sr. Associate - Data Scientist',
#  'Senior Data Scientist',
#  'Data Scientist',
#  'Data Scientist',
#  'Data Scientist / Machine learning Engineer',
#  'Junior Data Scientist']

# %%
Company = driver.find_elements_by_xpath('//a[@class="subTitle ellipsis fleft"]')
Company[:10]
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="aa473fde1dfc2e6b929b04777de67dc4", element="2a882a9c-ab4b-40a3-9746-83254b0291f0")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="aa473fde1dfc2e6b929b04777de67dc4", element="62302e24-3314-4733-b046-c2072a0fe0df")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="aa473fde1dfc2e6b929b04777de67dc4", element="4eedc95e-5237-4904-af83-353cba281964")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="aa473fde1dfc2e6b929b04777de67dc4", element="49a05732-4d82-4c80-8f1d-aafd9ace9acb")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="aa473fde1dfc2e6b929b04777de67dc4", element="b7e0097c-865d-4495-80ae-7f70b9725946")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="aa473fde1dfc2e6b929b04777de67dc4", element="f8eba443-65d9-467e-99a5-0cb3d3d4e1ec")>,
# ...

# %%
Company_Name = []
for i in Company:
    Company_Name.append(i.text)
Company_Name[:10]
# Out:
# ['GSK India',
#  'Applied Materials',
#  'MilliporeSigma',
#  'Flipkart',
#  'CHANGE LEADERS CONSULTING',
#  'GSK India',
#  'Thoucentric Technology Pvt ltd',
#  'Roposo',
#  'Leading US MNC into Analytics',
#  'Accenture']

# %%
location = driver.find_elements_by_xpath('//li[@class="fleft grey-text br2 placeHolderLi location"]')
location[:10]
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="aa473fde1dfc2e6b929b04777de67dc4", element="ae93eb67-c424-4a33-9528-872bc838f1c7")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="aa473fde1dfc2e6b929b04777de67dc4", element="cdc64668-c797-4f7b-85d9-14453a90ddb3")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="aa473fde1dfc2e6b929b04777de67dc4", element="c6bb99e4-bce3-44c8-a274-207b6faa9030")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="aa473fde1dfc2e6b929b04777de67dc4", element="84c6014d-6e96-43ae-8bbf-e2268327ed54")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="aa473fde1dfc2e6b929b04777de67dc4", element="3c33dcf8-3aea-4764-978c-1822bc17ac19")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="aa473fde1dfc2e6b929b04777de67dc4", element="4bf69e63-5fcb-4a95-a059-5953de9333af")>,
# ...

# %%
Location = []
for i in location:
    Location.append(i.text)
Location[:10]
# Out:
# ['Bangalore/Bengaluru',
#  'Bangalore/Bengaluru',
#  'Bangalore/Bengaluru',
#  'Bangalore/Bengaluru',
#  'Hyderabad/Secunderabad, Bangalore/Bengaluru',
#  'Bangalore/Bengaluru',
#  'Bangalore/Bengaluru(HSR Layout +2)',
#  'Bangalore/Bengaluru',
#  'Bangalore/Bengaluru, Delhi / NCR\n(WFH during Covid)',
#  'Bangalore/Bengaluru']

# %%
DataScience_Job_Listing = pd.DataFrame({})
DataScience_Job_Listing['Job_Title'] = Job_Title
DataScience_Job_Listing['Company_Name']=Company_Name
DataScience_Job_Listing['Location'] = Location
DataScience_Job_Listing = DataScience_Job_Listing[:10] 
DataScience_Job_Listing
# Out:
#                                     Job_Title                    Company_Name  \
# 0                       Senior Data Scientist                       GSK India
# 1                              Data Scientist               Applied Materials
# 2                    Analyst - Data Scientist                  MilliporeSigma
# 3                       Senior Data Scientist                        Flipkart
# 4              Sr. Associate - Data Scientist       CHANGE LEADERS CONSULTING
# 5                       Senior Data Scientist                       GSK India
# 6                              Data Scientist  Thoucentric Technology Pvt ltd
# 7                              Data Scientist                          Roposo
# 8  Data Scientist / Machine learning Engineer   Leading US MNC into Analytics
# 9                       Junior Data Scientist                       Accenture
#
#                                             Location
# 0                                Bangalore/Bengaluru
# ...

# %%
driver.close()

# %% [markdown]
# #### Q3: In this question you have to scrape data using the filters available on the webpage as shown below:
# ![image.png](attachment:image.png)
# ##### You have to use the location and salary filter.
# ###### You have to scrape data for “Data Scientist” designation for first 10 job results.
# ###### You have to scrape the job-title, job-location, company name, experience required.
# ###### The location filter to be used is “Delhi/NCR”.
# ###### The salary filter to be used is “3-6” lakhs
# ###### The task will be done as shown in the below steps:
#     1. first get the webpage https://www.naukri.com/
#     2. Enter “Data Scientist” in “Skill, Designations, and Companies” field.
#     3. Then click the search button.
#     4. Then apply the location filter and salary filter by checking the respective boxes
#     5. Then scrape the data for the first 10 jobs results you get.
#     6. Finally create a dataframe of the scraped data.
# ###### Note: All of the above steps have to be done in code. No step is to be done manually.

# %%
PATH = 'C:\Program Files (x86)\chromedriver.exe'
driver = webdriver.Chrome(PATH)

# %%
driver.get('https://www.naukri.com/')

# %%
driver.find_element_by_xpath('//*[@id="root"]/div[2]/div[3]/div/div/div[1]/div/div/div/input').send_keys('Data Scientist')

# %%
driver.find_element_by_xpath('//*[@id="root"]/div[2]/div[3]/div/div/div[6]').click()

# %%
driver.find_element_by_xpath('/html/body/div[1]/div[3]/div[2]/section[1]/div[2]/div[4]/div[2]/div[3]/label/i').click()

# %%
driver.find_element_by_xpath('/html/body/div[1]/div[3]/div[2]/section[1]/div[2]/div[5]/div[2]/div[2]/label/i').click()

# %%
title = driver.find_elements_by_xpath('//a[@class="title fw500 ellipsis"]')
title[:10]
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="efcca2786f98a317d2fb881315852941", element="a5b1eea9-da31-4f6c-891b-5645474f88e1")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="efcca2786f98a317d2fb881315852941", element="32ce4572-9967-4a23-a8c5-5bfcf372c41d")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="efcca2786f98a317d2fb881315852941", element="9807652b-a94a-4ec9-a033-1445cba1b36f")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="efcca2786f98a317d2fb881315852941", element="fe0e5b5d-b0f6-4ac3-9781-a2ad30f3bd21")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="efcca2786f98a317d2fb881315852941", element="91e9ce50-f060-49e7-9a48-d83e3fcf3dcf")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="efcca2786f98a317d2fb881315852941", element="306e732b-053a-4df6-b8f7-e080fff37f76")>,
# ...

# %%
Job_Title = []
for i in title:
    Job_Title.append(i.text)
Job_Title[:10]
# Out:
# ['Data Scientist/ Machine Learning, 2022 Passout Can also apply',
#  'Hiring For Senior Data Scientist-Noida',
#  'Senior Data Scientist',
#  'Data Scientist - Python/SQL',
#  'Data Scientist (freelance)',
#  'Lead Data Scientist',
#  'Data Scientist',
#  'Data Scientist',
#  'Data Scientist',
#  'Urgent Requirement || Data Scientist || Noida']

# %%
company = driver.find_elements_by_xpath('//a[@class="subTitle ellipsis fleft"]')
company[:10]
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="efcca2786f98a317d2fb881315852941", element="fdb0b788-191b-4478-8175-0dd1feff4edc")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="efcca2786f98a317d2fb881315852941", element="d994e1e8-584b-4af9-86fa-3d8530b3fa4d")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="efcca2786f98a317d2fb881315852941", element="0bacd83e-d6c9-44f7-bb57-747d48a45677")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="efcca2786f98a317d2fb881315852941", element="d680e979-6b31-47c6-9759-c244134cbe72")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="efcca2786f98a317d2fb881315852941", element="40e8328a-cd00-42d3-9d11-109d811cf580")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="efcca2786f98a317d2fb881315852941", element="8f92feca-bdde-44d2-adad-73d1ae8965bc")>,
# ...

# %%
Company_Name = []
for i in company:
    Company_Name.append(i.text)
Company_Name[:10]
# Out:
# ['Creative Hands HR Consultancy',
#  'Lumiq.ai',
#  'Optum',
#  'AVE-Promagne',
#  '2Coms',
#  'KIA INDIA PRIVATE LIMITED',
#  'BlackBuck',
#  'Country Veggie',
#  'Boston Consulting Group',
#  'HCL Technologies']

# %%
experience = driver.find_elements_by_xpath('//li[@class="fleft grey-text br2 placeHolderLi experience"]')
experience[:10]
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="efcca2786f98a317d2fb881315852941", element="8b55eee8-346e-4cde-9031-0e9b4bdbac1b")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="efcca2786f98a317d2fb881315852941", element="3bd7f648-f3c1-4f61-8166-5aa832e7786d")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="efcca2786f98a317d2fb881315852941", element="d2263c2d-3f2e-4f0c-bef1-b54812642df6")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="efcca2786f98a317d2fb881315852941", element="aad1e5a5-c44b-4ca9-b7d3-934f3a3895c1")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="efcca2786f98a317d2fb881315852941", element="0174443f-b1db-4782-9763-1bf6c313f264")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="efcca2786f98a317d2fb881315852941", element="b8a2e2b7-ad80-4431-8ba4-e9220c9e83f8")>,
# ...

# %%
Experience_Required = []
for i in experience:
    Experience_Required.append(i.text)
Experience_Required[:10]
# Out:
# ['0-4 Yrs',
#  '2-6 Yrs',
#  '2-7 Yrs',
#  '3-8 Yrs',
#  '2-7 Yrs',
#  '7-10 Yrs',
#  '3-7 Yrs',
#  '1-3 Yrs',
#  '2-5 Yrs',
#  '3-8 Yrs']

# %%
location = driver.find_elements_by_xpath('//li[@class="fleft grey-text br2 placeHolderLi location"]')
location[:10]
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="efcca2786f98a317d2fb881315852941", element="0fccb674-a960-4965-a073-cde80aa781f7")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="efcca2786f98a317d2fb881315852941", element="ae579bfb-2604-439e-867c-07e5a37e0740")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="efcca2786f98a317d2fb881315852941", element="7ea726d2-4464-4aab-af81-e9770ac781fe")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="efcca2786f98a317d2fb881315852941", element="0df3f840-2012-4e22-b55b-9df6098ca7aa")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="efcca2786f98a317d2fb881315852941", element="73e62b4b-6b17-4cb4-91d0-326b1ba0e656")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="efcca2786f98a317d2fb881315852941", element="f790f147-59c7-4f76-84d9-e1d23f906129")>,
# ...

# %%
Job_Location = []
for i in location:
    Job_Location.append(i.text)
Job_Location[:10]
# Out:
# ['Hyderabad/Secunderabad, Ahmedabad, Chennai, Bangalore/Bengaluru, Delhi / NCR, Mumbai (All Areas)',
#  'Noida, Greater Noida, Delhi / NCR',
#  'Noida',
#  'Noida, Kota, Mumbai, Chandigarh, Lucknow, Agra, Gurgaon/Gurugram, Jaipur, Bangalore/Bengaluru',
#  'New Delhi, Delhi',
#  'Gurgaon/Gurugram',
#  'Gurgaon, Bengaluru',
#  'Bharuch, Jaipur, Bhopal, Mumbai, Jhansi, Nagpur, Ghaziabad, Jaunpur, Kanpur, Delhi, Lucknow, Agra, Gurgaon, Rajkot, Bengaluru',
#  'New Delhi',
#  'Noida, Delhi / NCR']

# %%
df = pd.DataFrame({})
df['Job_Title']=Job_Title
df['Company_Name']=Company_Name
df['Experience_Required']=Experience_Required
df['Job_Location']=Job_Location
df=df[:10]
df
# Out:
#                                            Job_Title  \
# 0  Data Scientist/ Machine Learning, 2022 Passout...
# 1             Hiring For Senior Data Scientist-Noida
# 2                              Senior Data Scientist
# 3                        Data Scientist - Python/SQL
# 4                         Data Scientist (freelance)
# 5                                Lead Data Scientist
# 6                                     Data Scientist
# 7                                     Data Scientist
# 8                                     Data Scientist
# 9      Urgent Requirement || Data Scientist || Noida
#
#                     Company_Name Experience_Required  \
# 0  Creative Hands HR Consultancy             0-4 Yrs
# 1                       Lumiq.ai             2-6 Yrs
# 2                          Optum             2-7 Yrs
# 3                   AVE-Promagne             3-8 Yrs
# 4                          2Coms             2-7 Yrs
# 5      KIA INDIA PRIVATE LIMITED            7-10 Yrs
# ...

# %%
driver.close()

# %% [markdown]
# #### Q4: Scrape data of first 100 sunglasses listings on flipkart.com. You have to scrape four attributes:
#     1. Brand
#     2. Product Description
#     3. Price
# ##### The attributes which you have to scrape is ticked marked in the below image.
# ![image.png](attachment:image.png)
# ##### To scrape the data you have to go through following steps:
#     1. Go to Flipkart webpage by url : https://www.flipkart.com/
#     2. Enter “sunglasses” in the search field where “search for products, brands andmore” is written and click the search icon
#     3. After that you will reach to the page having a lot of sunglasses. From this pageyou can scrap the required data as usual.
#     4. After scraping data from the first page, go to the “Next” Button at the bottom ofthe page , then click on it.
#     5. Now scrape data from this page as usual
#     6. Repeat this until you get data for 100 sunglasses.
# ##### Note: That all of the above steps have to be done by coding only and not manually.

# %%
PATH = 'C:\Program Files (x86)\chromedriver.exe'
driver = webdriver.Chrome(PATH)

# %%
driver.get('https://www.flipkart.com/')

# %%
driver.find_element_by_xpath('/html/body/div[2]/div/div/button').click()

# %%
driver.find_element_by_xpath('/html/body/div[1]/div/div[1]/div[1]/div[2]/div[2]/form/div/div/input').send_keys('sunglasses')

# %%
driver.find_element_by_xpath('/html/body/div[1]/div/div[1]/div[1]/div[2]/div[2]/form/div/button').click()
time.sleep(5)

# %%
Product_Name = []
Product_Description = []
Price = []
Discount = []

while len(Product_Name) < 100:
    name = driver.find_elements_by_class_name('_2WkVRV')
    for i in name:
        Product_Name.append(i.text)
    description = driver.find_elements_by_class_name('IRpwTa')
    for i in description:
        Product_Description.append(i.text)
    price = driver.find_elements_by_class_name('_30jeq3')
    for i in price:
        Price.append(i.text)
    discount = driver.find_elements_by_class_name('_3Ay6Sb')
    for i in discount:
        Discount.append(i.text)
    driver.find_element_by_xpath('//*[@id="container"]/div/div[3]/div[1]/div[2]/div[12]/div/div/nav/a[11]/span')
Product_Name = Product_Name[:100]
Product_Description = Product_Description[:100]
Price = Price[:100]
Discount = Discount[:100]

# %%
Flipkart_Sunglasses = pd.DataFrame({})
Flipkart_Sunglasses['Product_Name']=Product_Name
Flipkart_Sunglasses['Product_Description']=Product_Description
Flipkart_Sunglasses['Price']=Price
Flipkart_Sunglasses['Discount']=Discount
Flipkart_Sunglasses
# Out:
#       Product_Name                                Product_Description Price  \
# 0     Silver Kartz           UV Protection Clubmaster Sunglasses (53)  ₹298
# 1    VINCENT CHASE             UV Protection Wayfarer Sunglasses (59)  ₹599
# 2             SRPM             UV Protection Wayfarer Sunglasses (50)  ₹199
# 3        Elligator                UV Protection Round Sunglasses (54)  ₹208
# 4         Fastrack      UV Protection Wayfarer Sunglasses (Free Size)  ₹709
# ..             ...                                                ...   ...
# 95          PIRASO                   Mirrored Aviator Sunglasses (32)  ₹202
# 96  kingsunglasses         UV Protection Round Sunglasses (Free Size)  ₹203
# 97  kingsunglasses  UV Protection, Riding Glasses, Mirrored Wayfar...  ₹225
# 98       Elligator                UV Protection Round Sunglasses (53)  ₹115
# 99  ROZZETTA CRAFT  UV Protection, Gradient Round Sunglasses (Free...  ₹629
#
#    Discount
# 0   80% off
# 1   70% off
# 2   84% off
# ...

# %%
driver.close()

# %% [markdown]
# #### Q5: Scrape 100 reviews data from flipkart.com for iphone11 phone. You have to go the link: https://www.flipkart.com/apple-iphone-11-black-64-gb-includes-earpods-power-adapter/product-reviews/itm0f37c2240b217?pid=MOBFKCTSVZAXUHGR&lid=LSTMOBFKCTSVZAXUHGR3IXQLM&marketplace=FLIPKART
#
# ![image.png](attachment:image.png)
#
# ##### As shown in the above page you have to scrape the tick marked attributes.These are:
#     1. Rating
#     2. Review summary
#     3. Full review
#     4. You have to scrape this data for first 100 reviews.
# ##### Note: All the steps required during scraping should be done through code only and not manually.

# %%
PATH = 'C:\Program Files (x86)\chromedriver.exe'
driver = webdriver.Chrome(PATH)

# %%
driver.get(' https://www.flipkart.com/apple-iphone-11-black-64-gb-includes-earpods-power-adapter/product-reviews/itm0f37c2240b217?pid=MOBFKCTSVZAXUHGR&lid=LSTMOBFKCTSVZAXUHGR3IXQLM&marketplace=FLIPKART')
time.sleep(2)

# %%
Heading = []
Rating = []

for i in range(1,11):
    print('Scrapping Page',i)
    x = f'//nav[@class="yFHi8N"]/a[{i}]'
    driver.find_element_by_xpath(x).click()
    time.sleep(4)
    if len(Heading)<100:
        heading = driver.find_elements_by_xpath('//div[@class="col _2wzgFH K0kLPL"]/div[1]')
        for i in heading:
            Heading.append(i.text.split('\n')[1])
            Rating.append(i.text.split('\n')[0])
    else:
        pass
        
len(Rating),len(Heading)
# Out:
# Scrapping Page 1
# Scrapping Page 2
# Scrapping Page 3
# Scrapping Page 4
# Scrapping Page 5
# Scrapping Page 6
# Scrapping Page 7
# Scrapping Page 8
# Scrapping Page 9
# Scrapping Page 10
# (100, 100)

# %%
Full_Review = []
for i in range(1,11):
    print('Scrapping Page',i)
    x = f'//nav[@class="yFHi8N"]/a[{i}]'
    driver.find_element_by_xpath(x).click()
    time.sleep(4)
    if len(Full_Review)<100:
        full_review = driver.find_elements_by_xpath('//div[@class="t-ZTKy"]/div[1]/div[1]')
        for i in full_review:
            Full_Review.append(i.text)
            time.sleep(1)
    else:
        pass
        
len(Full_Review)
# Out:
# Scrapping Page 1
#
#
# Scrapping Page 2
#
#
# Scrapping Page 3
#
#
# Scrapping Page 4
#
#
# Scrapping Page 5
#
#
# Scrapping Page 6
#
#
# Scrapping Page 7
#
#
# Scrapping Page 8
#
#
# Scrapping Page 9
#
#
# Scrapping Page 10
# 100

# %%
df_iPhone = pd.DataFrame({})
df_iPhone['Rating'] = Rating
df_iPhone['Heading'] = Heading
df_iPhone['Full_Review'] = Full_Review
df_iPhone
# Out:
#    Rating                Heading  \
# 0       5              Brilliant
# 1       5         Simply awesome
# 2       5    Best in the market!
# 3       5       Perfect product!
# 4       5              Fabulous!
# ..    ...                    ...
# 95      5                 Super!
# 96      5       Perfect product!
# 97      5         Classy product
# 98      5  Mind-blowing purchase
# 99      5                 Super!
#
#                                           Full_Review
# 0   The Best Phone for the Money\n\nThe iPhone 11 ...
# 1   Really satisfied with the Product I received.....
# 2   Great iPhone very snappy experience as apple k...
# 3   Amazing phone with great cameras and better ba...
# 4   This is my first iOS phone. I am very happy wi...
# ..                                                ...
# 95  Good display in this phone however screen is L...
# 96  At time of writing this review this phone proc...
# 97  This is very second time I am using iphone I a...
# ...

# %%
driver.close()

# %% [markdown]
# #### Q6: Scrape data for first 100 sneakers you find when you visit flipkart.com andsearch for “sneakers” in the search field.
# ##### You have to scrape 4 attributes of each sneaker:
#     1. Brand
#     2. Product Description
#     3. Price
# ##### As shown in the below image, you have to scrape the tick marked attributes.
# ![image.png](attachment:image.png)
#
# #### Note: All the steps required during scraping should be done through code only and not manually.

# %%
PATH = 'C:\Program Files (x86)\chromedriver.exe'
driver = webdriver.Chrome(PATH)

# %%
driver.get('https://www.flipkart.com/')

# %%
driver.find_element_by_xpath('/html/body/div[2]/div/div/button').click()

# %%
driver.find_element_by_xpath('/html/body/div[1]/div/div[1]/div[1]/div[2]/div[2]/form/div/div/input').send_keys('sneakers')

# %%
driver.find_element_by_xpath('/html/body/div[1]/div/div[1]/div[1]/div[2]/div[2]/form/div/button').click()
time.sleep(5)

# %%
Product_Name = []
Product_Description = []
Price = []
Discount = []

while len(Product_Name) < 100:
    
    name = driver.find_elements_by_class_name('_2WkVRV')
    for i in name:
        Product_Name.append(i.text)
    
    description = driver.find_elements_by_class_name('IRpwTa')
    for i in description:
        Product_Description.append(i.text)
    
    price = driver.find_elements_by_class_name('_30jeq3')
    for i in price:
        Price.append(i.text)
    
    discount = driver.find_elements_by_class_name('_3Ay6Sb')
    for i in discount:
        Discount.append(i.text)
    
    driver.find_element_by_xpath('//*[@id="container"]/div/div[3]/div[1]/div[2]/div[12]/div/div/nav/a[11]/span')

Product_Name = Product_Name[:100]
Product_Description = Product_Description[:100]
Price = Price[:100]
Discount = Discount[:100]

# %%
Flipkart_Sneakers = pd.DataFrame({})
Flipkart_Sneakers['Product_Name']=Product_Name
Flipkart_Sneakers['Product_Description']=Product_Description
Flipkart_Sneakers['Price']=Price
Flipkart_Sneakers['Discount']=Discount
Flipkart_Sneakers
# Out:
#            Product_Name                                Product_Description  \
# 0               EMPTILE   all white heartbeat casual shoe Sneakers For Men
# 1            HIGHLANDER                                   Sneakers For Men
# 2                Chevit  Super Stylish & Trendy Combo Pack of 02 Pairs ...
# 3              KWIK FIT  Kwik FIT casual sneaker shoes and partywear sh...
# 4              ASTEROID  Original Luxury Branded Fashionable Men's Casu...
# ..                  ...                                                ...
# 95               Rzisbo                                   Sneakers For Men
# 96            India hub  casual sneaker shoes for men kardam&sons Sneak...
# 97               Layasa                                   Sneakers For Men
# 98  World Wear Footwear  5011-Latest Collection Stylish & Trendy Casual...
# 99              Numenzo                        411 Casual Sneakers For Men
#
#    Price Discount
# 0   ₹347  65% off
# 1   ₹945  52% off
# ...

# %%
driver.close()

# %% [markdown]
# #### Q7: Go to the link - https://www.myntra.com/shoes Set Price filter to “Rs. 7149 to Rs. 14099 ” , Color filter to “Black”, as shown in the below image.
#
# ![image.png](attachment:image.png)
#
# ##### And then scrape First 100 shoes data you get. The data should include “Brand” of the shoes , Short Shoe description, price of the shoe as shown in the below image.
#
# ![image-2.png](attachment:image-2.png)
#
# ##### Note: Applying the filter and scraping the data, everything should be done through code only and there should not be any manual step.

# %%
PATH = 'C:\Program Files (x86)\chromedriver.exe'
driver = webdriver.Chrome(PATH)

# %%
driver.get('https://www.myntra.com/shoes')

# %%
driver.find_element_by_xpath('/html/body/div[2]/div/div[1]/main/div[3]/div[1]/section/div/div[5]/ul/li[2]/label/div').click()

# %%
driver.find_element_by_xpath('/html/body/div[2]/div/div[1]/main/div[3]/div[1]/section/div/div[6]/ul/li[1]/label/div').click()
time.sleep(2)

# %%
Brand = []
Description = []
Price = []

while len(Brand) <100:
    brand = driver.find_elements_by_class_name('product-brand')
    for i in brand:
        Brand.append(i.text)

    description = driver.find_elements_by_class_name('product-product')
    for i in description:
        Description.append(i.text)

    price = driver.find_elements_by_class_name("product-price")
    for i in price:
        Price.append(i.text.split(' ')[1].split('R')[0])
    
    driver.find_element_by_xpath('/html/body/div[2]/div/div[1]/main/div[3]/div[2]/div/div[2]/section/div[2]/ul/li[12]/a').click()
    time.sleep(5)
print(len(Brand))
print(len(Description))
print(len(Price))
# Out:
# 100
# 100
# 100

# %%
myntra_shoes = pd.DataFrame({})
myntra_shoes['Brand'] = Brand
myntra_shoes['Description'] = Description
myntra_shoes['Price'] = Price
myntra_shoes
# Out:
#                    Brand                                Description  Price
# 0                   ALDO                        Men Leather Loafers  11199
# 1                   Nike               Men Zoom Fly 4 Running Shoes  13045
# 2                   ALDO                  Men Leather Driving Shoes   9099
# 3                   Nike                  Men JORDAN ONE Basketball   8295
# 4               Skechers                 Men Max Cushioning Running   7649
# 5                   ALDO                       Men Printed Sneakers   9099
# 6           Hush Puppies          Men Solid Leather Formal Slip-Ons   7649
# 7                   ALDO                  Men Woven Design Sneakers  13999
# 8                 ADIDAS                 Men Dropset Training Shoes  11049
# 9                  ASICS                          Men Running Shoes   7999
# 10                  Puma                Men Colourblocked RS-Z Core   8499
# ...

# %%
driver.close()

# %% [markdown]
# #### Q8: Go to webpage https://www.amazon.in/ Enter “Laptop” in the search field and then click the search icon. Then set CPU Type filter to “Intel Core i7” and “Intel Core i9” as shown in the below image:
#
# ![image.png](attachment:image.png)
#
# #### After setting the filters scrape first 10 laptops data. You have to scrape 3 attributesfor each laptop:
#     1. Title
#     2. Ratings
#     3. Price
# #### As shown in the below image as the tick marked attributes
#
# ![image-2.png](attachment:image-2.png)
#
# #### Note: All the steps required during scraping should be done through code only and not manually.

# %%
PATH = 'C:\Program Files (x86)\chromedriver.exe'
driver = webdriver.Chrome(PATH)

# %%
driver.get('https://www.amazon.in/')

# %%
driver.find_element_by_name('field-keywords').send_keys('Laptop')

# %%
driver.find_element_by_id('nav-search-submit-button').click()

# %%
driver.find_element_by_xpath('/html/body/div[1]/div[2]/div[1]/div[2]/div/div[3]/span/div[1]/div/div/div[6]/ul[5]/li[11]/span/a/div/label/i').click()

# %%
name = driver.find_elements_by_xpath('//a[@class="a-link-normal s-underline-text s-underline-link-text s-link-style a-text-normal"]/span')
Name = []
for i in name:
    Name.append(i.text)
len(Name)
Name = Name[:5]

# %%
price = driver.find_elements_by_class_name("a-price-whole")
Price = []
for i in price:
    Price.append(i.text)
Price = Price[:5]

# %%
Amazon_Laptop = pd.DataFrame({})
Amazon_Laptop['Name'] = Name
Amazon_Laptop['Price'] = Price
Amazon_Laptop
# Out:
#                                                 Name     Price
# 0  Samsung Galaxy Book2 Pro 360 Intel 12th Gen i7...  1,29,990
# 1  Samsung Galaxy Book2 360 Intel 12th Gen i7 Evo...  1,05,990
# 2  ASUS VivoBook 14 (2021), 14-inch (35.56 cms) F...    57,490
# 3  Lenovo ThinkBook 15 Intel 11th Gen Core i7 15....    86,990
# 4  HP Pavilion 14, 11th Gen Intel Core i7-16GB RA...    86,990

# %%
driver.find_element_by_xpath('/html/body/div[1]/div[2]/div[1]/div[2]/div/div[3]/span/div[1]/div/div/div[6]/ul[4]/li[1]/span/a/span[2]').click()

# %%
driver.find_element_by_xpath('/html/body/div[1]/div[2]/div[1]/div[2]/div/div[3]/span/div[1]/div/div/div[6]/ul[4]/li[15]/span/a/div/label/i').click()

# %%
name = driver.find_elements_by_xpath('//a[@class="a-link-normal s-underline-text s-underline-link-text s-link-style a-text-normal"]/span')
Name = []
for i in name:
    Name.append(i.text)
len(Name)
Name = Name[:5]

# %%
price = driver.find_elements_by_class_name("a-price-whole")
Price = []
for i in price:
    Price.append(i.text)
Price = Price[:5]

# %%
Amazon_Laptop_i9 = pd.DataFrame({})
Amazon_Laptop_i9['Name'] = Name
Amazon_Laptop_i9['Price'] = Price
Amazon_Laptop_i9
# Out:
#                                                 Name     Price
# 0  Acer Predator Helios 300 11th Gen Intel Core i...  1,44,990
# 1  ASUS ROG Strix SCAR 15 (2022), 15.6-inch (39.6...  3,15,100
# 2  ASUS ROG Strix Scar 15 (2022), 15.6-inch (39.6...  2,85,990
# 3  ASUS TUF Gaming F15 (2021), 15.6" (39.62 cms) ...  1,77,885
# 4  Acer Predator Helios 300 11th Gen Intel Core i...  1,44,990

# %%
Amazone_Laptop = Amazon_Laptop.append(Amazon_Laptop_i9).reset_index(drop=True)

# %%
Amazone_Laptop
# Out:
#                                                 Name     Price
# 0  Samsung Galaxy Book2 Pro 360 Intel 12th Gen i7...  1,29,990
# 1  Samsung Galaxy Book2 360 Intel 12th Gen i7 Evo...  1,05,990
# 2  ASUS VivoBook 14 (2021), 14-inch (35.56 cms) F...    57,490
# 3  Lenovo ThinkBook 15 Intel 11th Gen Core i7 15....    86,990
# 4  HP Pavilion 14, 11th Gen Intel Core i7-16GB RA...    86,990
# 5  Acer Predator Helios 300 11th Gen Intel Core i...  1,44,990
# 6  ASUS ROG Strix SCAR 15 (2022), 15.6-inch (39.6...  3,15,100
# 7  ASUS ROG Strix Scar 15 (2022), 15.6-inch (39.6...  2,85,990
# 8  ASUS TUF Gaming F15 (2021), 15.6" (39.62 cms) ...  1,77,885
# 9  Acer Predator Helios 300 11th Gen Intel Core i...  1,44,990

# %%
driver.close()

# %% [markdown]
# #### Q10: Write a python program to scrape the salary data for Data Scientist designation.You have to scrape Company name, Number of salaries, Average salary, Minsalary, Max Salary.
# ##### The above task will be, done as shown in the below steps:
#     1. First get the webpage https://www.ambitionbox.com/
#     2. Click on the salaries option as shown in the image.
#     3. After reaching to the following webpage, In place of “Search Job Profile” enters “Data Scientist” and then click on “Data Scientist”.
#     You have to scrape the data ticked in the above image.
#     4. Scrape the data for the first 10 companies. Scrape the company name, total salary record, average salary, minimum salary, maximum salary, experience required.
#     5. Store the data in a dataframe.
#
# Note: All the steps required during scraping should be done through code only and not manually

# %%
PATH = 'C:\Program Files (x86)\chromedriver.exe'
driver = webdriver.Chrome(PATH)

# %%
driver.get(' https://www.ambitionbox.com/')

# %%
driver.find_element_by_xpath('/html/body/div[2]/nav/nav/a[4]').click()

# %%
driver.find_element_by_name("CompanyName").send_keys('Data Scientist')

# %%
driver.find_element_by_xpath('/html/body/div/div/div/div[2]/div/div/div/div[1]/span/div/div[2]/div[2]/div[2]/div/p').click()

# %%
driver.find_element_by_xpath('/html/body/div/div/div/div[2]/div/div/div/button/span').click()

# %%
company = driver.find_elements_by_xpath('//div[@class="name"]')

# %%
Company_Name = []
Total_Salary_Record = []
for i in company:
    Company_Name.append(i.text.split('\n')[0])
    Total_Salary_Record.append(i.text.split('\n')[1])
print(len(Company_Name))
print(len(Total_Salary_Record))
# Out:
# 10
# 10

# %%
experience = driver.find_elements_by_xpath('//div[@class="salaries one-line sbold-list-header"]/span')

# %%
Experience_Required = []
for i in experience:
    Experience_Required.append(i.text.split(' ')[0])
print(len(Experience_Required))
# Out:
# 10

# %%
average_salary = driver.find_elements_by_xpath('//div[@class="average-indicator-wrapper"]/p')

# %%
Average_Salary = []

for i in average_salary:
    Average_Salary.append(i.text)
Average_Salary= Average_Salary[9:]
print(len(Average_Salary))
# Out:
# 10

# %%
min_salary = driver.find_elements_by_class_name("salary-values")

Minimum_Salary = []
for i in min_salary:
    Minimum_Salary.append(i.text.split('\n')[0])
Minimum_Salary = Minimum_Salary[9:]
print(len(Minimum_Salary))
# Out:
# 10

# %%
max_salary = driver.find_elements_by_class_name("salary-values")

Maximum_Salary = []

for i in max_salary:
    try:
        Maximum_Salary.append(i.text.split('\n')[1])
    except:
        IndexError
Maximum_Salary = Maximum_Salary[3:]
print(len(Maximum_Salary))
# Out:
# 10

# %%
Ambitionbox_ds = pd.DataFrame({})
Ambitionbox_ds['Company_Name'] = Company_Name
Ambitionbox_ds['Total_Salary_Record'] = Total_Salary_Record
Ambitionbox_ds['Average_Salary'] = Average_Salary
Ambitionbox_ds['Minimum_Salary'] = Minimum_Salary
Ambitionbox_ds['Maximum_Salary'] = Maximum_Salary
Ambitionbox_ds['Experience_Required'] = Experience_Required
Ambitionbox_ds
# Out:
#     Company_Name Total_Salary_Record Average_Salary Minimum_Salary  \
# 0            TCS      (765 Salaries)         ₹ 7.6L         ₹ 4.5L
# 1      Accenture      (456 Salaries)        ₹ 12.5L         ₹ 5.5L
# 2            IBM      (365 Salaries)        ₹ 13.1L         ₹ 5.3L
# 3      Cognizant      (296 Salaries)         ₹ 9.7L         ₹ 5.0L
# 4      Capgemini      (283 Salaries)         ₹ 8.4L         ₹ 4.6L
# 5        Infosys      (214 Salaries)         ₹ 9.0L         ₹ 4.5L
# 6  Tech Mahindra      (209 Salaries)         ₹ 7.8L         ₹ 4.1L
# 7          Wipro      (209 Salaries)         ₹ 9.6L         ₹ 4.5L
# 8       Deloitte      (151 Salaries)        ₹ 13.4L         ₹ 7.0L
# 9       Ericsson      (147 Salaries)        ₹ 13.8L         ₹ 5.5L
#
#   Maximum_Salary Experience_Required
# 0        ₹ 15.6L                 2-9
# 1        ₹ 23.0L                 2-9
# 2        ₹ 25.0L                2-12
# 3        ₹ 18.0L                2-10
# 4        ₹ 14.6L                 2-8
# ...

# %%
driver.close()
