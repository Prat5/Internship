# %% [markdown]
# ## 10) Write a python program to scrape first 10 product details which include product name , price , Image URL from https://www.bewakoof.com/women-tshirts?ga_q=tshirts .

# %%
from bs4 import BeautifulSoup
import requests
import lxml
import numpy as np
import pandas as pd

# %%
import os
from selenium import webdriver
PATH = 'C:\Program Files (x86)\chromedriver.exe'
url = 'https://www.bewakoof.com/women-clothing'
driver = webdriver.Chrome(PATH)
driver.get(url)

page = driver.page_source
soup = BeautifulSoup(page)
bewakoof = []
for main_file in soup.find_all('div',class_="productCardDetail"):
        name = main_file.find('h3').text
        price = main_file.find('span',attrs={'class' :"discountedPriceText "})
        actual_price = main_file.find('span',class_="actualPriceText ")
        if (len(name))>0 or len(price)>0:
            bewakoof.append([name,price,actual_price])
df = pd.DataFrame(bewakoof,columns=['Name','Discounted Price','Actual Price'])
df
# Out:
# <ipython-input-20-f51fcd4553a0>:5: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(PATH)
#                                                  Name Discounted Price  \
# 0   Women's Purple Dressed Up Snoopy Boyfriend T-s...             None
# 1       Women's Purple Music Escape Boyfriend T-shirt             None
# 2   Women's Black One with the Universe Boyfriend ...             None
# 3    Women's Green Sleepy Head (DL) Boyfriend T-shirt             None
# 4   Women's Black Dressed Up Snoopy Boyfriend T-shirt             None
# 5        Women's White Music Escape Boyfriend T-shirt             None
# 6    Women's Purple Stay Weird (DL) Boyfriend T-shirt             None
# 7   Women's Purple Unique Personality Boyfriend T-...             None
# 8          Women's Red Busy Doing Nothing 2.0 T-shirt             None
# 9          Women's White Music Bear Boyfriend T-shirt             None
# ...
